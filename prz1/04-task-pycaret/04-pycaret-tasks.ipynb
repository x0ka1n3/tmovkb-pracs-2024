# %% [markdown]
# # PyCaret - открытая low-code библиотека машинного обучения на Python

# %% [markdown]
# ![PyCaret.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Install numpy lib to avoid errors in using PyCaret
# pip install numpy==1.20.3 scikit-learn==0.23.2
#
# pip install --pre pycaret

# %%
# 3. Import PyCaret regression libs
from pycaret.regression import *

# %%
# 4. Import PyCaret regression libs and review PyCaret's datasets
from pycaret.datasets import get_data
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
# 5. Load dataset 'Insurance'
# While loading you should press 'Enter' in field below
data=get_data('insurance')
reg = setup(
    data=data, 
    target='charges', 
    train_size=0.8, 
    session_id=10,
    normalize=True
)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_609c9_row10_col1, #T_609c9_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_609c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_609c9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_609c9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_609c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_609c9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_609c9_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_609c9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_609c9_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_609c9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_609c9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_609c9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_609c9_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_609c9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_609c9_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_609c9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_609c9_row5_col1" class="data row5 col1" >(1070, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_609c9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_609c9_row6_col1" class="data row6 col1" >(268, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_609c9_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_609c9_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_609c9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_609c9_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_609c9_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_609c9_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_609c9_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_609c9_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_609c9_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_609c9_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_609c9_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_609c9_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_609c9_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_609c9_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_609c9_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_609c9_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_609c9_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_609c9_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_609c9_row16_col0" class="data row16 col0" >Normalize</td>
#       <td id="T_609c9_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_609c9_row17_col0" class="data row17 col0" >Normalize method</td>
#       <td id="T_609c9_row17_col1" class="data row17 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_609c9_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_609c9_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_609c9_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_609c9_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_609c9_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_609c9_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_609c9_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_609c9_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_609c9_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_609c9_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_609c9_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_609c9_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_609c9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_609c9_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_609c9_row24_col1" class="data row24 col1" >d846</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 6. Answer the questions
# * How many categorical and numeric features in dataset?
# * In what proportion dataset splits in train and test sets?
# * Are gpu use in experiments?
# * What normalization method used?

# %%
# 7. Review normalized features
get_config('X')
# Out:
#       age     sex        bmi  children smoker     region
# 0      19    male  35.529999         0     no  northwest
# 1      50    male  27.455000         1     no  northeast
# 2      18  female  30.115000         0     no  northeast
# 3      18    male  34.099998         0     no  southeast
# 4      53    male  29.480000         0     no  southeast
# ...   ...     ...        ...       ...    ...        ...
# 1333   50    male  34.200001         2    yes  southwest
# 1334   26  female  40.185001         0     no  northwest
# 1335   19    male  27.264999         2     no  northwest
# 1336   57    male  40.945000         0     no  northeast
# 1337   42    male  35.970001         2     no  southeast
#
# [1338 rows x 6 columns]

# %% [markdown]
# Функция get_config('X') возвращает набор признаков после предобработки.
#
# Как можно увидеть, чсленные значения признаков были нормализованы с помощью Z-оценки, а категориальные призанки были закодированы с помощью метода быстрого кодирования ("one-hot encoding"). Очень важно проверить результаты нормализации, в некоторых случаях она может быть выполнена некорректно, что повлияет на возможность обучить классификатр и получить верные занчения.
#
# Нормализация Z-оценки относится к процессу нормализации каждого значения в наборе данных, так что среднее значение всех значений равно 0, а стандартное отклонение равно 1.
#
# Мы используем следующую формулу для нормализации z-оценки для каждого значения в наборе данных:
#
# Новое значение = (x – μ) / σ
#
# где:
#
# х : Исходное значение
#
# μ : Среднее значение данных
#
# σ : стандартное отклонение данных

# %%
# 8. Prepare to magic;) Evaluate all models by 1 line of code 
# compare models
best = compare_models()
# Out:
# <style type="text/css">
# #T_9cc12 th {
#   text-align: left;
# }
# #T_9cc12_row0_col0, #T_9cc12_row0_col6, #T_9cc12_row1_col0, #T_9cc12_row1_col1, #T_9cc12_row1_col2, #T_9cc12_row1_col3, #T_9cc12_row1_col4, #T_9cc12_row1_col5, #T_9cc12_row1_col6, #T_9cc12_row2_col0, #T_9cc12_row2_col1, #T_9cc12_row2_col2, #T_9cc12_row2_col3, #T_9cc12_row2_col4, #T_9cc12_row2_col5, #T_9cc12_row2_col6, #T_9cc12_row3_col0, #T_9cc12_row3_col1, #T_9cc12_row3_col2, #T_9cc12_row3_col3, #T_9cc12_row3_col4, #T_9cc12_row3_col5, #T_9cc12_row3_col6, #T_9cc12_row4_col0, #T_9cc12_row4_col1, #T_9cc12_row4_col2, #T_9cc12_row4_col3, #T_9cc12_row4_col4, #T_9cc12_row4_col5, #T_9cc12_row4_col6, #T_9cc12_row5_col0, #T_9cc12_row5_col1, #T_9cc12_row5_col2, #T_9cc12_row5_col3, #T_9cc12_row5_col4, #T_9cc12_row5_col5, #T_9cc12_row5_col6
#       <td id="T_9cc12_row5_col5" class="data row5 col5" >0.4647</td>
#       <td id="T_9cc12_row5_col6" class="data row5 col6" >0.3373</td>
#       <td id="T_9cc12_row5_col7" class="d

# %%
plot_model(best)

# %%
# Feature Importance
plot_model(best, plot = 'feature')

# %%
plot_model(best, plot = 'learning')

# %% [markdown]
# Выполните следующие задания:
# * Импортируйте набор данных 'diabetes'
# * Выполните импорт всех библиотек из модуля classification библиотеки pycaret
# * Настройте эксперимент, цель - значения столбца 'Class variable'
# * Выполните поиск наилучшей модели
# * Определите наиболее значимые признаки
# * Выполните графическое построение наилучшей модели

# %%
from pycaret.classification import *

data=get_data('diabetes')
experiment = setup(
    data=data, 
    target='Class variable'
)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1
# <style type="text/css">
# #T_68a69_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_68a69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68a69_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_68a69_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68a69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68a69_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_68a69_row0_col1" class="data row0 col1" >6540</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68a69_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_68a69_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68a69_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_68a69_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68a69_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_68a69_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68a69_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_68a69_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_68a69_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_68a69_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_68a69_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_68a69_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_68a69_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_68a69_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_68a69_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_68a69_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_68a69_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_68a69_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_68a69_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_68a69_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_68a69_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_68a69_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_68a69_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_68a69_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_68a69_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_68a69_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_68a69_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_68a69_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_68a69_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_68a69_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_68a69_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_68a69_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_68a69_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_68a69_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_68a69_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_68a69_row18_col1" class="data row18 col1" >4ef9</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('X')
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           0
# 2                           4
# 3                           2
# 4                           2
# ..                        ...
# 763                         1
# 764                         2
# 765                         3
# 766                         4
# 767                        13
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  125
# 1                                                  102
# 2                                                   90
# 3                                                  122
# 4                                                  129
# ..                                                 ...
# 763                                                115
# 764                                                 84
# 765                                                150
# 766                                                115
# 767                                                158
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                  76                                 0
# 1                                  52                                 0
# 2                                  88                                47
# 3                                  52                                43
# 4                                   0                                 0
# ..                                ...                               ...
# 763                                70                                30
# 764                                50                                23
# 765                                76                                 0
# 766                                72                                 0
# 767                               114                                 0
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                                 0
# 1                                 0
# 2                                54
# 3                               158
# 4                                 0
# ..                              ...
# 763                              96
# 764                              76
# 765                               0
# 766                               0
# 767                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                         33.799999
# 1                                         25.100000
# 2                                         37.700001
# 3                                         36.200001
# 4                                         38.500000
# ..                                              ...
# 763                                       34.599998
# 764                                       30.400000
# 765                                       21.000000
# 766                                       28.900000
# 767                                       42.299999
#
#      Diabetes pedigree function  Age (years)
# 0                         0.121           54
# 1                         0.078           21
# 2                         0.362           29
# 3                         0.816           28
# 4                         0.304           41
# ..                          ...          ...
# 763                       0.529           32
# 764                       0.968           21
# 765                       0.207           37
# 766                       0.376           46
# 767                       0.257           44
#
# [768 rows x 8 columns]

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_23041 th {
#   text-align: left;
# }
# #T_23041_row0_col0, #T_23041_row0_col2, #T_23041_row0_col3, #T_23041_row0_col5, #T_23041_row0_col6, #T_23041_row0_col7, #T_23041_row1_col0, #T_23041_row1_col3, #T_23041_row1_col4, #T_23041_row1_col5, #T_23041_row1_col6, #T_23041_row1_col7, #T_23041_row2_col0, #T_23041_row2_col1, #T_23041_row2_col2, #T_23041_row2_col3, #T_23041_row2_col4, #T_23041_row2_col5, #T_23041_row2_col6, #T_23041_row2_col7, #T_23041_row3_col0, #T_23041_row3_col1, #T_23041_row3_col2, #T_23041_row3_col3, #T_23041_row3_col4, #T_23041_row4_col0, #T_23041_row4_col1, #T_23041_row4_col2, #T_23041_row4_col3, #T_23041_row4_col4, #T_23041_row4_col5, #T_23041_row4_col6, #T_23041_row4_col7, #T_23041_row5_col0, #T_23041_row5_col1, #T_23041_row5_col2, #T_23041_row5_col3, #T_23041_row5_col4, #T_23041_row5_col5, #T_23041_row5_col6, #T_23041_row5_col7, #T_23041_row6_col0, #T_23041_row6_col1, #T_23041_row6_col2, #T_23041_row6_col3, #T_23041_row6_col4, #T_23041_row6_col5, #T_23041_row6_col6, #T_23041_row6_col7, #T_23041_row7_col0, #T_23041_row7_col1, #T_23041_row7_col2, #T_23041_row7_col3, #T_23041_row7_col4, #T_23041_row7_col5, #T_23041_row7_col6, #T_23041_row7_col7, #T_23041_row8_col0, #T_23041_row8_col1, #T_23041_row8_col2, #T_23041_row8_col3, #T_23041_row8_col4, #T_23041_row8_col5, #T_23041_row8_col6, #T_23041_row8_col7, #T_23041_row9_col0, #T_23041_row9_col1, #T_23041_row9_col2, #T_23041_row9_col3, #T_23041_row9_col4, #T_23041_row9_col5, #T_23041_row9_col6, #T_23041_row9_col7, #T_23041_row10_col0, #T_23041_row10_col1, #T_23041_row10_col2, #T_23041_row10_col3, #T_23041_row10_col4, #T_23041_row10_col5, #T_23041_row10_col6, #T_23041_row10_col7, #T_23041_row11_col0, #T_23041_row11_col1, #T_23041_row11_col2, #T_23041_row11_col3, #T_23041_row11_col4, #T_23041_row11_col5, #T_23041_row11_col6, #T_23041_row11_col7, #T_23041_row12_col0, #T_23041_row12_col1, #T_23041_row12_col2, #T_23041_row12_col3, #T_23041_row12_col4, #T_23041_row12_col5, #T_23041_row12_col6, #T_23041_row12_col7, #T_23041_row13_col0, #T_23041_row13_col1, #T_23041_row13_col2, #T_23041_row13_col4, #T_23041_row13_col5, #T_23041_row13_col6, #T_23041_row13_col7 {
#   text-align: left;
# }
# #T_23041_row0_col1, #T_23041_row0_col4, #T_23041_row1_col1, #T_23041_row1_col2, #T_23041_row3_col5, #T_23041_row3_col6, #T_23041_row3_col7, #T_23041_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_23041_row0_col8, #T_23041_row3_col8, #T_23041_row4_col8, #T_23041_row5_col8, #T_23041_row6_col8, #T_23041_row7_col8, #T_23041_row8_col8, #T_23041_row9_col8, #T_23041_row10_col8, #T_23041_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_23041_row1_col8, #T_23041_row2_col8, #T_23041_row12_col8, #T_23041_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_23041">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23041_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_23041_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_23041_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_23041_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_23041_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_23041_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_23041_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_23041_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_23041_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23041_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_23041_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_23041_row0_col1" class="data row0 col1" >0.7561</td>
#       <td id="T_23041_row0_col2" class="data row0 col2" >0.8329</td>
#       <td id="T_23041_row0_col3" class="data row0 col3" >0.5348</td>
#       <td id="T_23041_row0_col4" class="data row0 col4" >0.7039</td>
#       <td id="T_23041_row0_col5" class="data row0 col5" >0.6004</td>
#       <td id="T_23041_row0_col6" class="data row0 col6" >0.4310</td>
#       <td id="T_23041_row0_col7" class="data row0 col7" >0.4442</td>
#       <td id="T_23041_row0_col8" class="data row0 col8" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_23041_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_23041_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_23041_row1_col1" class="data row1 col1" >0.7561</td>
#       <td id="T_23041_row1_col2" class="data row1 col2" >0.8338</td>
#       <td id="T_23041_row1_col3" class="data row1 col3" >0.5401</td>
#       <td id="T_23041_row1_col4" class="data row1 col4" >0.6993</td>
#       <td id="T_23041_row1_col5" class="data row1 col5" >0.6039</td>
#       <td id="T_23041_row1_col6" class="data row1 col6" >0.4330</td>
#       <td id="T_23041_row1_col7" class="data row1 col7" >0.4441</td>
#       <td id="T_23041_row1_col8" class="data row1 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_23041_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_23041_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_23041_row2_col1" class="data row2 col1" >0.7543</td>
#       <td id="T_23041_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_23041_row2_col3" class="data row2 col3" >0.5295</td>
#       <td id="T_23041_row2_col4" class="data row2 col4" >0.7038</td>
#       <td id="T_23041_row2_col5" class="data row2 col5" >0.5971</td>
#       <td id="T_23041_row2_col6" class="data row2 col6" >0.4266</td>
#       <td id="T_23041_row2_col7" class="data row2 col7" >0.4402</td>
#       <td id="T_23041_row2_col8" class="data row2 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_23041_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_23041_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_23041_row3_col1" class="data row3 col1" >0.7523</td>
#       <td id="T_23041_row3_col2" class="data row3 col2" >0.8142</td>
#       <td id="T_23041_row3_col3" class="data row3 col3" >0.6135</td>
#       <td id="T_23041_row3_col4" class="data row3 col4" >0.6592</td>
#       <td id="T_23041_row3_col5" class="data row3 col5" >0.6290</td>
#       <td id="T_23041_row3_col6" class="data row3 col6" >0.4446</td>
#       <td id="T_23041_row3_col7" class="data row3 col7" >0.4497</td>
#       <td id="T_23041_row3_col8" class="data row3 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_23041_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_23041_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_23041_row4_col1" class="data row4 col1" >0.7432</td>
#       <td id="T_23041_row4_col2" class="data row4 col2" >0.8116</td>
#       <td id="T_23041_row4_col3" class="data row4 col3" >0.5567</td>
#       <td id="T_23041_row4_col4" class="data row4 col4" >0.6641</td>
#       <td id="T_23041_row4_col5" class="data row4 col5" >0.6021</td>
#       <td id="T_23041_row4_col6" class="data row4 col6" >0.4151</td>
#       <td id="T_23041_row4_col7" class="data row4 col7" >0.4212</td>
#       <td id="T_23041_row4_col8" class="data row4 col8" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_23041_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_23041_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_23041_row5_col1" class="data row5 col1" >0.7413</td>
#       <td id="T_23041_row5_col2" class="data row5 col2" >0.8076</td>
#       <td id="T_23041_row5_col3" class="data row5 col3" >0.5082</td>
#       <td id="T_23041_row5_col4" class="data row5 col4" >0.6753</td>
#       <td id="T_23041_row5_col5" class="data row5 col5" >0.5729</td>
#       <td id="T_23041_row5_col6" class="data row5 col6" >0.3947</td>
#       <td id="T_23041_row5_col7" class="data row5 col7" >0.4067</td>
#       <td id="T_23041_row5_

# %%
plot_model(best, plot = 'feature')

# %%
plot_model(best)

# %%
plot_model(best, plot = 'learning')
